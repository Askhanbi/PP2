# %%
x = 20
y = 10

print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x % y)
print(x ** y)
print(x // y)
print(x & y)
print(x | y)
print(x ^ y)
print(~x)

print(x is y)
print(x is not y)
# Out:
# 30
# 10
# 200
# 2.0
# 0
# 10240000000000
# 2
# 0
# 30
# 30
# -21
# False
# True
